# %%
import tensorflow as tf #pip install tensorflow
import numpy as np #pip install numpy
image = r'C:\Users\shuai\OneDrive\Documents\ImageProcessing\DogCat_1.jpg'

# %% [markdown]
# # First Method

# %%
from IPython.display import Image
Image(image,width=224,height=224)

# %% [markdown]
# # Second Method

# %%
import matplotlib.pyplot as plt #pip install matplotlib

# %%
img = plt.imread(image)
imgplot = plt.imshow(img)

# %% [markdown]
# # Third Method

# %%
import cv2 #pip install opencv-python

# %%
imgg = cv2.imread(image)
plt.imshow(imgg)

# %%
#let's change GBR to RGB
plt.imshow(cv2.cvtColor(imgg, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Fourth Method

# %%
from PIL import Image

# %%
imgg = Image.open(image)
imgg
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1016x1023 at 0x173094F7F70>

# %%
# resize this image into (224,224)
imgg.resize((224,244))
# Out:
# <PIL.Image.Image image mode=RGB size=224x244 at 0x1731ABA79A0>
